# %%
from gpt.onnx_slope_pipeline import ONNXSlopePipeline
from lib.utils.path import model_path, raw_data_path

depth_nums = [('001', 'ZED1_KSC_001032'), ('007', 'ZED4_KSC_010545')]

for _, num in enumerate(depth_nums):
    depth_path = raw_data_path(num[0])

    pipe = ONNXSlopePipeline(
        onnx_path=model_path() / 'pidnet.onnx',
        config_path=depth_path / f'Depth_{num[0]}.conf',
    )

    prefix = num[1]

    res = pipe.run_pipeline(
        left_path=depth_path / f'{prefix}_left.png',
        disp_path=depth_path / f'{prefix}_disp16.png',
        conf_path=depth_path / f'{prefix}_confidence_save.png',
    )
    print(res)
# Out:
# [SLOPE] stats: {'fx': 1394.83, 'fy': 1394.83, 'cx': 932.377, 'cy': 559.96, 'baseline_m': 0.120009, 'disp_scale': 16.0, 'roi_ratio': 0.5, 'conf_th': 40, 'min_d': 0.5, 'max_d': 12.0, 'conf_ratio': 0.15224199459876545, 'disp_ratio': 0.5481481481481482, 'dist_ratio': 0.27607011959876543, 'external_mask_ratio': 0.15166811342592593, 'final_valid_ratio': 0.0038131751543209877, 'final_valid_count': 7907}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 16
#       9 pipe = ONNXSlopePipeline(
#      10     onnx_path=model_path() / 'pidnet.onnx',
#      11     config_path=depth_path / f'Depth_{num[0]}.conf',
#      12 )
#      14 prefix = num[1]
# ---> 16 res = pipe.run_pipeline(
#      17     left_path=depth_path / f'{prefix}_left.png',
#      18     disp_path=depth_path / f'{prefix}_disp16.png',
#      19     conf_path=depth_path / f'{prefix}_confidence_save.png',
#      20 )
#      21 print(res)
#
# File C:\Workspaces\projects\wheel-safe\src\gpt\onnx_slope_pipeline.py:18, in run_pipeline(self, left_path, disp_path, conf_path)
#      12 from lib.utils.path import output_path
#      15 class ONNXSlopePipeline:
#      16     def __init__(
#      17         self,
# ---> 18         *,
#      19         onnx_path: str | Path,
#      20         config_path: str | Path,  # Depth_*.conf
#      21         mode: str = 'LEFT_CAM_FHD',
#      22         morph_kernel: int = 5,
#      23         # slope params
#      24         disp_scale: float = 16.0,
#      25         conf_th: int = 40,
#      26         min_d: float = 0.5,
#      27         max_d: float = 12.0,
#      28         roi_ratio: float = 0.5,
#      29         ransac_iters: int = 500,
#      30         ransac_inlier_thresh_m: float = 0.03,
#      31         max_points: int = 50000,
#      32         debug_print: bool = True,
#      33     ):
#      34         self.onnx_path = Path(onnx_path)
#      35         self.config_path = Path(config_path)
#
# File C:\Workspaces\projects\wheel-safe\src\gpt\slope_aggregator.py:63, in calculate_slope(self, disp_path, conf_img_path, external_mask)
#      57 self.max_points = int(max_points)
#      59 self.debug_print = bool(debug_print)
#      61 self.cam = self._load_camera_params(
#      62     self.config_path, self.mode, self.stereo_section
# ---> 63 )
#
# KeyError: 'plane_normal'
