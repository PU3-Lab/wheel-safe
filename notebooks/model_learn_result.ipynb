# %% [markdown]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:02<00:00,  2.09it/s, val_mse=1.6907]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:02<00:00,  2.18it/s, val_mse=1.6907]
# [Epoch 1 | Step 50/674] train_mse=2.3494, val_mse=1.6907, r2=-0.009181274586394839
# --- 모델 저장됨 (Best Loss: 1.6907) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.13it/s, val_mse=1.5316]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.67it/s, val_mse=1.5316]
# [Epoch 1 | Step 100/674] train_mse=1.9789, val_mse=1.5316, r2=0.1032666093009833
# --- 모델 저장됨 (Best Loss: 1.5316) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.14it/s, val_mse=1.5034]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.68it/s, val_mse=1.5034]
# [Epoch 1 | Step 150/674] train_mse=1.8270, val_mse=1.5034, r2=0.117539799714523
# --- 모델 저장됨 (Best Loss: 1.5034) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.13it/s, val_mse=1.5081]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.64it/s, val_mse=1.5081]
# [Epoch 1 | Step 200/674] train_mse=1.7652, val_mse=1.5081, r2=0.11392048193838666
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.19it/s, val_mse=1.5899]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.76it/s, val_mse=1.5899]
# [Epoch 1 | Step 250/674] train_mse=1.6986, val_mse=1.5899, r2=0.06506854334849133
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.22it/s, val_mse=1.4977]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.75it/s, val_mse=1.4977]
# [Epoch 1 | Step 300/674] train_mse=1.6541, val_mse=1.4977, r2=0.12889428560004867
# --- 모델 저장됨 (Best Loss: 1.4977) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.22it/s, val_mse=1.4969]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.76it/s, val_mse=1.4969]
# [Epoch 1 | Step 350/674] train_mse=1.6242, val_mse=1.4969, r2=0.11609139589503337
# --- 모델 저장됨 (Best Loss: 1.4969) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.22it/s, val_mse=1.4783]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.76it/s, val_mse=1.4783]
# [Epoch 1 | Step 400/674] train_mse=1.5913, val_mse=1.4783, r2=0.1302855347660733
# --- 모델 저장됨 (Best Loss: 1.4783) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.20it/s, val_mse=1.4686]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.74it/s, val_mse=1.4686]
# [Epoch 1 | Step 450/674] train_mse=1.5678, val_mse=1.4686, r2=0.15147343005722902
# --- 모델 저장됨 (Best Loss: 1.4686) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.20it/s, val_mse=1.4513]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.73it/s, val_mse=1.4513]
# [Epoch 1 | Step 500/674] train_mse=1.5390, val_mse=1.4513, r2=0.156573378312567
# --- 모델 저장됨 (Best Loss: 1.4513) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.18it/s, val_mse=1.4518]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.67it/s, val_mse=1.4518]
# [Epoch 1 | Step 550/674] train_mse=1.5255, val_mse=1.4518, r2=0.1571304978979885
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.12it/s, val_mse=1.4456]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.60it/s, val_mse=1.4456]
# [Epoch 1 | Step 600/674] train_mse=1.5070, val_mse=1.4456, r2=0.17186465896619907
# --- 모델 저장됨 (Best Loss: 1.4456) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.12it/s, val_mse=1.4210]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.70it/s, val_mse=1.4210]
# [Epoch 1 | Step 650/674] train_mse=1.4898, val_mse=1.4210, r2=0.18876570485190491
# --- 모델 저장됨 (Best Loss: 1.4210) ---
# Epoch 1: 100%|███████████████████████████████████████████████████████████████████| 674/674 [18:28<00:00,  1.65s/it, train_mse=1.4813]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.12it/s, val_mse=1.5426]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.66it/s, val_mse=1.5426]
# [Epoch 2 | Step 50/674] train_mse=1.2975, val_mse=1.5426, r2=0.12481554398908334
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.13it/s, val_mse=1.3904]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.68it/s, val_mse=1.3904]
# [Epoch 2 | Step 100/674] train_mse=1.2987, val_mse=1.3904, r2=0.21149511990367653
# --- 모델 저장됨 (Best Loss: 1.3904) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.16it/s, val_mse=1.6510]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.65it/s, val_mse=1.6510]
# [Epoch 2 | Step 150/674] train_mse=1.2947, val_mse=1.6510, r2=0.038858735009149825
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.16it/s, val_mse=1.3901]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.67it/s, val_mse=1.3901]
# [Epoch 2 | Step 200/674] train_mse=1.2982, val_mse=1.3901, r2=0.22215196482751776
# --- 모델 저장됨 (Best Loss: 1.3901) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.15it/s, val_mse=1.4017]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.69it/s, val_mse=1.4017]
# [Epoch 2 | Step 250/674] train_mse=1.2959, val_mse=1.4017, r2=0.19973196711385832
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.15it/s, val_mse=1.3965]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.70it/s, val_mse=1.3965]
# [Epoch 2 | Step 300/674] train_mse=1.2842, val_mse=1.3965, r2=0.20952784520344236
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.15it/s, val_mse=1.4358]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.72it/s, val_mse=1.4358]
# [Epoch 2 | Step 350/674] train_mse=1.2848, val_mse=1.4358, r2=0.18297747236162365
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.15it/s, val_mse=1.4242]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.68it/s, val_mse=1.4242]
# [Epoch 2 | Step 400/674] train_mse=1.2833, val_mse=1.4242, r2=0.183407289037544
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.14it/s, val_mse=1.5319]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.71it/s, val_mse=1.5319]
# [Epoch 2 | Step 450/674] train_mse=1.2874, val_mse=1.5319, r2=0.12272072331959316
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.14it/s, val_mse=1.4105]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.66it/s, val_mse=1.4105]
# [Epoch 2 | Step 500/674] train_mse=1.2848, val_mse=1.4105, r2=0.19357191756060865
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.14it/s, val_mse=1.4636]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.69it/s, val_mse=1.4636]
# [Epoch 2 | Step 550/674] train_mse=1.2908, val_mse=1.4636, r2=0.1722712619133473
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.16it/s, val_mse=1.3700]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.75it/s, val_mse=1.3700]
# [Epoch 2 | Step 600/674] train_mse=1.2938, val_mse=1.3700, r2=0.21741831686640256
# --- 모델 저장됨 (Best Loss: 1.3700) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.21it/s, val_mse=1.3831]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.80it/s, val_mse=1.3831]
# [Epoch 2 | Step 650/674] train_mse=1.2933, val_mse=1.3831, r2=0.21251965197004097
# Epoch 2: 100%|███████████████████████████████████████████████████████████████████| 674/674 [18:31<00:00,  1.65s/it, train_mse=1.2940]
# >>> [알림] 모든 레이어 활성화 (Fine-tuning 모드)
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.18it/s, val_mse=1.3443]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.72it/s, val_mse=1.3443]
# [Epoch 3 | Step 50/674] train_mse=1.2567, val_mse=1.3443, r2=0.2127215593034706
# --- 모델 저장됨 (Best Loss: 1.3443) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.20it/s, val_mse=1.2501]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.74it/s, val_mse=1.2501]
# [Epoch 3 | Step 100/674] train_mse=1.2211, val_mse=1.2501, r2=0.29462455117640485
# --- 모델 저장됨 (Best Loss: 1.2501) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.20it/s, val_mse=1.2087]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.67it/s, val_mse=1.2087]
# [Epoch 3 | Step 150/674] train_mse=1.1742, val_mse=1.2087, r2=0.3256946975325282
# --- 모델 저장됨 (Best Loss: 1.2087) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.22it/s, val_mse=1.1371]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.80it/s, val_mse=1.1371]
# [Epoch 3 | Step 200/674] train_mse=1.1170, val_mse=1.1371, r2=0.38555952708654384
# --- 모델 저장됨 (Best Loss: 1.1371) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.20it/s, val_mse=1.1197]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.72it/s, val_mse=1.1197]
# [Epoch 3 | Step 250/674] train_mse=1.0976, val_mse=1.1197, r2=0.393482833358613
# --- 모델 저장됨 (Best Loss: 1.1197) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.21it/s, val_mse=1.2707]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.73it/s, val_mse=1.2707]
# [Epoch 3 | Step 300/674] train_mse=1.0682, val_mse=1.2707, r2=0.27727134622525496
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.24it/s, val_mse=1.0654]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.82it/s, val_mse=1.0654]
# [Epoch 3 | Step 350/674] train_mse=1.0484, val_mse=1.0654, r2=0.43220372371362825
# --- 모델 저장됨 (Best Loss: 1.0654) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.22it/s, val_mse=1.1141]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.75it/s, val_mse=1.1141]
# [Epoch 3 | Step 400/674] train_mse=1.0310, val_mse=1.1141, r2=0.3993487667545351
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.22it/s, val_mse=1.0345]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.76it/s, val_mse=1.0345]
# [Epoch 3 | Step 450/674] train_mse=1.0093, val_mse=1.0345, r2=0.44678247363773615
# --- 모델 저장됨 (Best Loss: 1.0345) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.20it/s, val_mse=1.0532]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.76it/s, val_mse=1.0532]
# [Epoch 3 | Step 500/674] train_mse=0.9948, val_mse=1.0532, r2=0.4477430325395203
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.19it/s, val_mse=1.1536]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.73it/s, val_mse=1.1536]
# [Epoch 3 | Step 550/674] train_mse=0.9753, val_mse=1.1536, r2=0.39396848430317444
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.19it/s, val_mse=1.0321]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.73it/s, val_mse=1.0321]
# [Epoch 3 | Step 600/674] train_mse=0.9618, val_mse=1.0321, r2=0.45216262640669036
# --- 모델 저장됨 (Best Loss: 1.0321) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.16it/s, val_mse=1.1549]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.62it/s, val_mse=1.1549]
# [Epoch 3 | Step 650/674] train_mse=0.9543, val_mse=1.1549, r2=0.37241222130741203
# Epoch 3: 100%|███████████████████████████████████████████████████████████████████| 674/674 [21:34<00:00,  1.92s/it, train_mse=0.9498]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.24it/s, val_mse=1.2029]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.78it/s, val_mse=1.2029]
# [Epoch 4 | Step 50/674] train_mse=0.7946, val_mse=1.2029, r2=0.3325042175259232
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.24it/s, val_mse=1.0253]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.79it/s, val_mse=1.0253]
# [Epoch 4 | Step 100/674] train_mse=0.7510, val_mse=1.0253, r2=0.4437283004480317
# --- 모델 저장됨 (Best Loss: 1.0253) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.24it/s, val_mse=0.9736]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.78it/s, val_mse=0.9736]
# [Epoch 4 | Step 150/674] train_mse=0.7460, val_mse=0.9736, r2=0.48637077202874246
# --- 모델 저장됨 (Best Loss: 0.9736) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.21it/s, val_mse=1.1412]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.79it/s, val_mse=1.1412]
# [Epoch 4 | Step 200/674] train_mse=0.7411, val_mse=1.1412, r2=0.36886980524704327
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.22it/s, val_mse=1.0469]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.84it/s, val_mse=1.0469]
# [Epoch 4 | Step 250/674] train_mse=0.7471, val_mse=1.0469, r2=0.4241216338539876
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.25it/s, val_mse=1.0316]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.84it/s, val_mse=1.0316]
# [Epoch 4 | Step 300/674] train_mse=0.7306, val_mse=1.0316, r2=0.4541793658911457
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.17it/s, val_mse=1.0028]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.74it/s, val_mse=1.0028]
# [Epoch 4 | Step 350/674] train_mse=0.7309, val_mse=1.0028, r2=0.46048490135774256
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.18it/s, val_mse=1.0519]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.77it/s, val_mse=1.0519]
# [Epoch 4 | Step 400/674] train_mse=0.7279, val_mse=1.0519, r2=0.43684390508941007
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.15it/s, val_mse=0.9871]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.75it/s, val_mse=0.9871]
# [Epoch 4 | Step 450/674] train_mse=0.7290, val_mse=0.9871, r2=0.48388939421415866
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.22it/s, val_mse=1.0048]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.81it/s, val_mse=1.0048]
# [Epoch 4 | Step 500/674] train_mse=0.7218, val_mse=1.0048, r2=0.4810561107016973
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.13it/s, val_mse=0.9916]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.36it/s, val_mse=0.9916]
# [Epoch 4 | Step 550/674] train_mse=0.7236, val_mse=0.9916, r2=0.48821817514324717
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.24it/s, val_mse=1.0653]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.83it/s, val_mse=1.0653]
# [Epoch 4 | Step 600/674] train_mse=0.7240, val_mse=1.0653, r2=0.4283925695920495
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.19it/s, val_mse=0.9916]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.76it/s, val_mse=0.9916]
# [Epoch 4 | Step 650/674] train_mse=0.7202, val_mse=0.9916, r2=0.4787363085156835
# Epoch 4: 100%|███████████████████████████████████████████████████████████████████| 674/674 [21:27<00:00,  1.91s/it, train_mse=0.7241]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.21it/s, val_mse=1.0075]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.75it/s, val_mse=1.0075]
# [Epoch 5 | Step 50/674] train_mse=0.6382, val_mse=1.0075, r2=0.47063288571525586
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.22it/s, val_mse=1.0493]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:58<00:00,  2.78it/s, val_mse=1.0493]
# [Epoch 5 | Step 100/674] train_mse=0.6477, val_mse=1.0493, r2=0.44652776512059567
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.21it/s, val_mse=0.9742]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.76it/s, val_mse=0.9742]
# [Epoch 5 | Step 150/674] train_mse=0.6346, val_mse=0.9742, r2=0.4873894134570652
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.20it/s, val_mse=0.9791]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.67it/s, val_mse=0.9791]
# [Epoch 5 | Step 200/674] train_mse=0.6261, val_mse=0.9791, r2=0.481564994571015
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.20it/s, val_mse=0.9776]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.76it/s, val_mse=0.9776]
# [Epoch 5 | Step 250/674] train_mse=0.6228, val_mse=0.9776, r2=0.48873680785049756
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.19it/s, val_mse=0.9628]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.69it/s, val_mse=0.9628]
# [Epoch 5 | Step 300/674] train_mse=0.6237, val_mse=0.9628, r2=0.47806298295399774
# --- 모델 저장됨 (Best Loss: 0.9628) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.19it/s, val_mse=0.9781]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.71it/s, val_mse=0.9781]
# [Epoch 5 | Step 350/674] train_mse=0.6223, val_mse=0.9781, r2=0.4879512981781893
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.17it/s, val_mse=0.9881]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.69it/s, val_mse=0.9881]
# [Epoch 5 | Step 400/674] train_mse=0.6258, val_mse=0.9881, r2=0.4705216768699444
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.22it/s, val_mse=1.0043]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [00:59<00:00,  2.77it/s, val_mse=1.0043]
# [Epoch 5 | Step 450/674] train_mse=0.6238, val_mse=1.0043, r2=0.4725414842497474
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.18it/s, val_mse=1.0392]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.80it/s, val_mse=1.0392]
# [Epoch 5 | Step 500/674] train_mse=0.6223, val_mse=1.0392, r2=0.4346393384429671
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.18it/s, val_mse=0.9569]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.76it/s, val_mse=0.9569]
# [Epoch 5 | Step 550/674] train_mse=0.6175, val_mse=0.9569, r2=0.49705505153732543
# --- 모델 저장됨 (Best Loss: 0.9569) ---
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.14it/s, val_mse=1.0222]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:01<00:00,  2.71it/s, val_mse=1.0222]
# [Epoch 5 | Step 600/674] train_mse=0.6161, val_mse=1.0222, r2=0.44260756686174985
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.16it/s, val_mse=1.0064]
# Evaluating: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:00<00:00,  2.64it/s, val_mse=1.0064]
# [Epoch 5 | Step 650/674] train_mse=0.6155, val_mse=1.0064, r2=0.46615656672817674
# Epoch 5: 100%|███████████████████████████████████████████████████████████████████| 674/674 [21:34<00:00,  1.92s/it, train_mse=0.6148]

# %% [markdown]
# testing...: 100%|██████████████████████████████████████████████████████████████████| 131/131 [01:03<00:00,  2.06it/s, val_mse=1.0147]
# ## ✅ 최종 테스트 결과
# * LOSS: 1.0147
# * MAE (평균 각도 오차): 1.43°
# * R2 Score: 0.5188
# * MSE: 3.9304
