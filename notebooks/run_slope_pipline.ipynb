# %%
import cv2
import numpy as np

from lib.utils.path import raw_data_path
from v3.slope_pipeline import COLOR_MAP, SlopePipeline
from v3.viz_map import report_2, report_road

image_names = [
    'ZED1_KSC_001032',
    'ZED4_KSC_010824',
    'ZED4_KSC_010525',
    'ZED4_KSC_010615',
]

foder_nums = ['001', '007', '007', '007']

slope_pipeline = SlopePipeline()

for _, (name, num) in enumerate(list(zip(image_names, foder_nums, strict=False))):
    folder_path = raw_data_path(num)
    conf_file = folder_path / f'Depth_{num}.conf'
    img_path = folder_path / f'{name}_left.png'
    conf_img = folder_path / f'{name}_confidence.png'
    disp_img = folder_path / f'{name}_disp16.png'

    disp_map = cv2.imread(str(disp_img), cv2.IMREAD_UNCHANGED).astype(np.float32) / 16
    conf_map = (
        cv2.imread(str(conf_img), cv2.IMREAD_UNCHANGED).astype(np.float32) / 255.0
    )

    slope_pipeline.set_config_params(conf_file)

    pred, img = slope_pipeline.run(img_path)
    slope, mask = slope_pipeline.estimate(conf_map, disp_map)

    palette = np.array(COLOR_MAP, dtype=np.uint8)
    report_2(img_path, pred, conf_map, disp_map, palette)

    if slope is not None:
        report_road(img_path, mask, slope)
# Out:
# Attention!!!
# Loaded 453 parameters!
# Over!!!
# 모델 세팅 완료
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 32
#      29 slope_pipeline = SlopePipeline(conf_file)
#      31 pred, img = slope_pipeline.run(img_path)
# ---> 32 slope, mask = slope_pipeline.estimate(conf_map, disp_map)
#      34 palette = np.array(COLOR_MAP, dtype=np.uint8)
#      35 report_2(img_path, pred, conf_map, disp_map, palette)
#
# File C:\Workspaces\projects\wheel-safe\src\v3\slope_pipeline.py:44, in SlopePipeline.estimate(self, conf_map, disp_map)
#      43 def estimate(self, conf_map, disp_map):
# ---> 44     return self.slop_estimator.run(self.pred, conf_map, disp_map)
#
# File C:\Workspaces\projects\wheel-safe\src\v3\slope_estimator.py:88, in SlopeEstimator.run(self, pred_index, conf_map, disp_map)
#      84 # 2. Disparity를 실제 거리(Depth, Z)로 변환
#      85 # 공식: Z = (fx * baseline) / disparity
#      86 # 주의: disp_map의 값이 픽셀 단위인지 확인이 필요합니다.
#      87 actual_disp = disp_map[y_coords, x_coords]
# ---> 88 z_depth = (self.cam_params['fx'] * self.cam_params['baseline']) / actual_disp
#      90 # 3. 3D 공간 좌표 복원 (카메라 좌표계)
#      91 # X = (x - cx) * Z / fx
#      92 # Y = (y - cy) * Z / fy
#      93 real_x = (x_coords - self.cam_params['cx']) * z_depth / self.cam_params['fx']
#
# AttributeError: 'SlopeEstimator' object has no attribute 'cam_params'

# %%
from lib.utils.path import raw_path
from v3.create_labels import save_to_csv

save_to_csv(raw_path())
# save_to_csv(raw_path()) -> 모든 폴더 검색
# save_to_csv(raw_path(), 'Depth_005') -> Depth_005번만 검색
